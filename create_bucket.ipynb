# %%
import boto3
from boto3.s3.transfer import S3Transfer
import os
import logging
from botocore.exceptions import ClientError
import import_ipynb
from display import main
from display_KV import main_KV
# Out:
# importing Jupyter notebook from display.ipynb
# importing Jupyter notebook from display_KV.ipynb

# %%
def create_bucket(bucket_name, region=None):
    """Create an S3 bucket in a specified region

    If a region is not specified, the bucket is created in the S3 default
    region (us-east-1).

    :param bucket_name: Bucket to create
    :param region: String region to create bucket in, e.g., 'us-west-2'
    :return: True if bucket created, else False
    """

    # Create bucket
    try:
        if region is None:
            s3_client = boto3.client('s3')
            s3_client.create_bucket(Bucket=bucket_name)
        else:
            s3_client = boto3.client('s3', region_name=region)
            location = {'LocationConstraint': region}
            s3_client.create_bucket(Bucket=bucket_name,
                                    CreateBucketConfiguration=location)
    except ClientError as e:
        print(1)
        logging.error(e)
        return False
    return True

# %%
def upload_file_s3():
    # upload file to s3 bucket
    bucket = 'arthashastra-1'
    s3_client = boto3.client('s3')
    transfer = S3Transfer(s3_client)
    rootdir = 'C:/Users/lenovo/PycharmProjects/aws-textract1/Images/'

    for folder in os.listdir(rootdir):

        folderdir = rootdir+folder
        for pages in os.listdir(folderdir):
            print('pages :' + pages)
            keys = folder+'/'+pages
            print(keys)
            transfer.upload_file(folderdir+'/'+pages,bucket,  keys)
        print('==============')
    #return "ALL FILES SUCCESSFULLY UPLOADED"

# %%
def textract_job():
    s3_client = boto3.client('s3')
    tess = boto3.client('textract', region_name='ap-south-1')
    bucket = 'arthashastra-1'
    print(1)
    print("MAKE CHOICE FOR THE INPUT:")
    print("=============================")
    print("main_KV reflects KEY_VALUE PAIR \n main reflects TABLE OUTPUT")
    choice(input('enter the input'))

# %%
def choice(inpt):
    if inpt == 'KV':
        output_file = 'C:/Users/lenovo/PycharmProjects/aws-textract1/Output_KV.csv'
        path = 'C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder'
        with open(output_file, "wt") as fout:
            files = os.listdir(path)
            for file in files:
                fle = os.listdir(path+'/'+file)
                for f in fle:
                    file_name = path+'/'+file+'/'+f
                    print(f)
                    main_KV(file_name,fout)
    else:
        output_file = 'C:/Users/lenovo/PycharmProjects/aws-textract1/Output.csv'
        path = 'C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder'
        with open(output_file, "wt") as fout:
            files = os.listdir(path)
            for file in files:
                fle = os.listdir(path+'/'+file)
                for f in fle:
                    file_name = path+'/'+file+'/'+f
                    print(f)
                    main(file_name,fout)

# %%
print(textract_job())
# Out:
# 1
# MAKE CHOICE FOR THE INPUT:
# =============================
# main_KV reflects KEY_VALUE PAIR
#  main reflects TABLE OUTPUT
# enter the inputKV
# Invoice_2_0.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_0.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Yes  : X
# Hindi  :
# No  : X
# English  : X
# Permanent Account Number (PAN) of the company  : AAACC4209Q
# (d) *Telephone number with STD code  : 04426568404
# (e) Website  :
# Global Location Number (GLN) of the company  :
# (c) *e-mail ID of the company  : vitoon@cp-india.com
# (i) * Corporate Identification Number (CIN) of the company  : U01211TN1997PTC038419
# (iii) Date of Incorporation  : 6/16/97
# (ii) (a) Name of the company  : CPF (INDIA) PRIVATELIMITED
# (iv) Type of the Company  : Private Company
# (b) Registered office address  : NO 40 2ND STREET, 1ST FLOOR, F2, SPARTON NAGAR, MOGAPPAIREAST CHENNAI Chennai Tamil Nadu 200027
# Company limited by shares  : Indian Non-Government company
# Category of the Company  : Sub-category of the Company
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_1.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_1.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Yes  : X
# No  :
# (a) If yes, date of AGM  : 30/09/2016
# (b) Due date of AGM  : 30/09/2016
# To date  : 31/03/2016
# (vii) *Financial year From date  : 01/04/2015
# *Number of business activities  : 2
# Name of the company  : CPF Investment Limited
# Holding/ Subsidiary/Associate/ Joint Venture  : Holding
# *No. of Companies for which information is to be given  : 1 Pre-fill All
# % of shares held  : 99.99
# Issued capital  :
# S.No  : 1
# Class of Shares  : EQUITY SHARES
# CIN / FCRN  :
# Number of classes  : 1
# Subscribed capital  : Paid up capital
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_10.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_10.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# *Number of meetings held  : 18
# Number of meetings held  : 3
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_11.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_11.png
#
#
# == FOUND KEY : VALUE pairs ===
#
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_12.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_12.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Yes  : X .
# No  :
# Nil  : X
# Number of CEO, CFO and Company secretary whose remuneration details to be entered  : 1
# Details of penalty/ punishment  :
# Number of Managing Director, Whole-time Directors and/or Manager whose remuneration details to be entered  : 0
# Name of the Act and section under which penalised / punished  :
# B. If No, give reasons/observations  :
# Name of the court/ concerned Authority  :
# Number of other directors whose remuneration details to be entered  : 2
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_13.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_13.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Associate  :
# No  :
# Fellow  : X
# dated  : 03/09/2016
# Yes  : X
# Certificate of practice number  : 6549
# To be digitally signed by  : RAMASUB RAMANIAM
# DIN of the director  : 00326042
# Name  : C RAMASUBRAMANIAM
# Director  : VITOON Digitally signed by VITOON KITTIMONG KITTIMONGKOLSUK Date: 2016.12.02 KOLSUK 17:13:42 +05'30'
# Name of the court/ concerned Authority  :
# I am Authorised by the Board of Directors of the company vide resolution no.  : 07
# Amount of compounding (in Rupees)  :
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_14.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_14.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Membership number  : 6125
# Company Secretary  :
# Company secretary in practice  : X
# Certificate of practice number  : 6549
# List of shareholders.pdt FORM MGT 8.pdf  :
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_2.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_2.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Authorised Capital  : 0
# Number of classes  : 0
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_3.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_3.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Details of stock split/consolidation during the year (for each class of shares)  : 0
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_4.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_4.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Yes  :
# No  :
# Not Applicable  :
# Amount per Share/ Debenture/Unit (in Rs.)  :
# Date of the previous annual general meeting  :
# Date of registration of transfer (Date Month Year)  :
# Ledger Folio of Transferor  :
# Number of Shares/ Debentures/ Units Transferred  :
# Type of transfer  :
# Nil  : X
# After split /  : Consolidation
# Ledger Folio of Transferee  :
# middle name  :
# Surname  :
# first name  :
#  : - Equity, 2- Preference Shares,3 - Debentures, 4 - Stock
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_5.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_5.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Amount per Share/ Debenture/Unit (in Rs.)  :
# Date of registration of transfer (Date Month Year)  :
# Number of Shares/ Debentures/ Units Transferred  :
# Ledger Folio of Transferee  :
# Ledger Folio of Transferor  :
# Surname  :
# Type of transfer  :
# middle name  :
# Transferor's Name  :
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_6.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_6.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# (ii) Net worth of the Company  : 6581460951
# (i) Turnover  : 35068730336
# Equity  : Preference
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_7.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_7.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Total number of shareholders (promoters)  :
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_8.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_8.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Non-executive  :
# Executive  :
# Percentage of shares held by directors as at the end of year  :
# Total number of shareholders (Promoters+Public/ Other than promoters)  : 2
# Total number of shareholders (other than promoters)  : 0
# Number of directors at the end of the year  :
# Category  :
#
#  Do you want to search a value for a key? (enter "n" for exit)
#
#  Enter a search key:n
# The value is:
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# Invoice_2_9.png
# Image loaded C:/Users/lenovo/PycharmProjects/aws-textract1/Untitled Folder/Invoice_2/Invoice_2_9.png
#
#
# == FOUND KEY : VALUE pairs ===
#
# Number of Directors and Key managerial personnel (who is not director) as on the financial year end date  : 6
# (ii) Particulars of change in director(s) and Key managerial personnel during the year  : 6
#
#  Do you want to search a value for a key? (enter "n" for exit) n
# None
